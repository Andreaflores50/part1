# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

project = pd.read_csv('../part1/Project_data.csv')
print(project.shape)
project.head()
# Out:
# (1564, 42)
#    Obs_No     AR #                                        Industry   Obs_Year  \
# 0       1  ABE1000                                  Wholesale Trade         0
# 1       2  ABE1000                                  Wholesale Trade         1
# 2       3  ABI1002  Technology, Professional, and Business Services         1
# 3       4  ACC1004  Technology, Professional, and Business Services         0
# 4       5  ACC1004  Technology, Professional, and Business Services         1
#
#    Year Live  DaysSinceLive  Reported Number of Employees  EE Year Count  \
# 0       2011           1823                           222            217
# 1       2011           2188                           222            218
# 2       2016            240                           648            381
# 3       2010           2261                           220            220
# 4       2010           2626                           220            220
#
# ...

# %%
# %matplotlib inline

# %%
## only use rows that have a target value (2018 and 2017 data)
model_data = project.loc[:,"Model "]==1
project = project.loc[model_data, :]
print(project.shape)
# Out:
# (1099, 42)

# %%
project.columns
# Out:
# Index(['Obs_No', 'AR #', 'Industry ', 'Obs_Year', 'Year Live', 'DaysSinceLive',
#        'Reported Number of Employees', 'EE Year Count', 'ARR Year Growth',
#        'ARR Start', 'ARR_EndOfYear', 'BumpOut75K', 'growth_percent',
#        'Product 1', 'Product 2 ', 'Product 3', 'Product 4', 'Product 5',
#        'Product 6', 'Product 7', 'Product 8', 'Product 9', 'Product 10',
#        'Product 11', 'Product 12', 'Product 13', 'Product 14', 'Product 15',
#        'Product 16', 'Product 17', 'Product 18', 'Total Product Count',
#        'Category_Account Health', 'RefNo_Cumulative', 'Connections Attendance',
#        'Training Hours', 'Training Students', 'Percent of Book', 'ACT Score',
#        'BI Score', 'Ave P_Score', 'Model '],
#       dtype='object')

# %%
project.isnull().sum()
# Out:
# Obs_No                          0
# AR #                            0
# Industry                        0
# Obs_Year                        0
# Year Live                       0
# DaysSinceLive                   0
# Reported Number of Employees    0
# EE Year Count                   0
# ARR Year Growth                 0
# ARR Start                       0
# ARR_EndOfYear                   0
# BumpOut75K                      0
# growth_percent                  0
# Product 1                       0
# Product 2                       0
# Product 3                       0
# Product 4                       0
# Product 5                       0
# Product 6                       0
# Product 7                       0
# Product 8                       0
# Product 9                       0
# Product 10                      0
# Product 11                      0
# Product 12                      0
# Product 13                      0
# Product 14                      0
# ...

# %%
project = project.drop("Obs_No", axis="columns")
project = project.drop("AR #", axis="columns")
project = project.drop("Obs_Year", axis="columns")
project = project.drop("Year Live", axis="columns")
project = project.drop("Reported Number of Employees", axis="columns")
project = project.drop("ARR_EndOfYear", axis="columns")
project = project.drop("RefNo_Cumulative", axis="columns")
project = project.drop("BumpOut75K", axis="columns")

# %%
project.head()
# Out:
#                                          Industry   DaysSinceLive  \
# 0                                  Wholesale Trade           1823
# 1                                  Wholesale Trade           2188
# 2  Technology, Professional, and Business Services            240
# 3  Technology, Professional, and Business Services           2261
# 4  Technology, Professional, and Business Services           2626
#
#    EE Year Count  ARR Year Growth  ARR Start  growth_percent  Product 1  \
# 0            217           4753.0      66054        0.071956          1
# 1            218           5866.0      70807        0.082845          1
# 2            381          39173.0      73369        0.533918          1
# 3            220           3192.0      31944        0.099925          1
# 4            220           3504.0      35136        0.099727          1
#
#    Product 2   Product 3  Product 4   ...    Total Product Count  \
# 0           0          1          0   ...                      7
# ...

# %%
#g =sns.pairplot(project)
#axes = pd.plotting.scatter_matrix(project.loc[:,:], figsize=(20,20))

# %%
project.hist(figsize=(30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1869e828>,
# ...
#       dtype=object)

# %%
g = sns.lmplot(x="ACT Score",
              y="growth_percent", 
              data=project,
              aspect=1.5, 
              scatter_kws={"alpha":0.2}
              )
# Out:
# /Users/andreaflores/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
g = sns.lmplot(x="ACT Score",
              y="ARR Year Growth", 
              data=project,
              aspect=1.5, 
              scatter_kws={"alpha":0.2}
              )
# Out:
# /Users/andreaflores/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
g = sns.lmplot(x="ARR Start",
              y="ARR Year Growth", 
              data=project,
              aspect=1.5, 
              scatter_kws={"alpha":0.2}
              )

# %%
g = sns.lmplot(x="Ave P_Score",
              y="ARR Year Growth", 
              data=project,
              aspect=1.5, 
              scatter_kws={"alpha":0.2}
              )

# %%
g = sns.lmplot(x="BI Score",
              y="ARR Year Growth", 
              data=project,
              aspect=1.5, 
              scatter_kws={"alpha":0.2}
              )

# %%
g = sns.lmplot(x="Percent of Book",
              y="ARR Year Growth", 
              data=project,
              aspect=1.5, 
              scatter_kws={"alpha":0.2}
              )

# %%
g = sns.lmplot(x="EE Year Count",
              y="ARR Year Growth", 
              data=project,
              aspect=1.5, 
              scatter_kws={"alpha":0.2}
              )

# %%
g = sns.lmplot(x="DaysSinceLive",
              y="ARR Year Growth", 
              data=project,
              aspect=1.5, 
              scatter_kws={"alpha":0.2}
              )

# %%
g = sns.lmplot(x="Connections Attendance",
              y="ARR Year Growth", 
              data=project,
              aspect=1.5, 
              scatter_kws={"alpha":0.2}
              )

# %%
g = sns.lmplot(x="Training Hours",
              y="ARR Year Growth", 
              data=project,
              aspect=1.5, 
              scatter_kws={"alpha":0.2}
              )

# %%
g = sns.lmplot(x="Training Students",
              y="ARR Year Growth", 
              data=project,
              aspect=1.5, 
              scatter_kws={"alpha":0.2}
              )

# %%
g = sns.lmplot(x="Total Product Count",
              y="ARR Year Growth", 
              data=project,
              aspect=1.5, 
              scatter_kws={"alpha":0.2}
              )

# %%
dummies=pd.get_dummies(project, columns=["Industry ", "Category_Account Health", "Connections Attendance"])
dummies.columns
# Out:
# Index(['DaysSinceLive', 'EE Year Count', 'ARR Year Growth', 'ARR Start',
#        'growth_percent', 'Product 1', 'Product 2 ', 'Product 3', 'Product 4',
#        'Product 5', 'Product 6', 'Product 7', 'Product 8', 'Product 9',
#        'Product 10', 'Product 11', 'Product 12', 'Product 13', 'Product 14',
#        'Product 15', 'Product 16', 'Product 17', 'Product 18',
#        'Total Product Count', 'Training Hours', 'Training Students',
#        'Percent of Book', 'ACT Score', 'BI Score', 'Ave P_Score', 'Model ',
#        'Industry _Agriculture and Natural Resources', 'Industry _Construction',
#        'Industry _Education', 'Industry _Finance and Insurance',
#        'Industry _Healthcare', 'Industry _Manufacturing',
#        'Industry _Non-Profits, Membership, and Human Services',
#        'Industry _Public Sector', 'Industry _Real Estate',
#        'Industry _Restaurants and Hospitality', 'Industry _Retail',
#        'Industry _Sports and Entertainment',
# ...

# %%
project.loc[:, "Industry "].value_counts()
#project.loc[:, "Category_Account Health"].value_counts()
#project.loc[:, "Connections Attendance"].value_counts()
# Out:
# Technology, Professional, and Business Services    326
# Manufacturing                                      176
# Finance and Insurance                              144
# Healthcare                                          85
# Wholesale Trade                                     82
# Non-Profits, Membership, and Human Services         75
# Real Estate                                         39
# Retail                                              37
# Transportation and Warehousing                      31
# Education                                           23
# Construction                                        18
# Sports and Entertainment                            18
# Utilities and Mining                                17
# Public Sector                                       12
# Restaurants and Hospitality                         11
# Agriculture and Natural Resources                    5
# Name: Industry , dtype: int64

# %%
dummies=dummies.drop("Category_Account Health_1", axis ="columns")
dummies=dummies.drop("Industry _Technology, Professional, and Business Services", axis ="columns")
dummies=dummies.drop("Connections Attendance_0", axis ="columns")
dummies.columns
# Out:
# Index(['DaysSinceLive', 'EE Year Count', 'ARR Year Growth', 'ARR Start',
#        'growth_percent', 'Product 1', 'Product 2 ', 'Product 3', 'Product 4',
#        'Product 5', 'Product 6', 'Product 7', 'Product 8', 'Product 9',
#        'Product 10', 'Product 11', 'Product 12', 'Product 13', 'Product 14',
#        'Product 15', 'Product 16', 'Product 17', 'Product 18',
#        'Total Product Count', 'Training Hours', 'Training Students',
#        'Percent of Book', 'ACT Score', 'BI Score', 'Ave P_Score', 'Model ',
#        'Industry _Agriculture and Natural Resources', 'Industry _Construction',
#        'Industry _Education', 'Industry _Finance and Insurance',
#        'Industry _Healthcare', 'Industry _Manufacturing',
#        'Industry _Non-Profits, Membership, and Human Services',
#        'Industry _Public Sector', 'Industry _Real Estate',
#        'Industry _Restaurants and Hospitality', 'Industry _Retail',
#        'Industry _Sports and Entertainment',
# ...

# %%
dummies.dtypes
# Out:
# DaysSinceLive                                              int64
# EE Year Count                                              int64
# ARR Year Growth                                          float64
# ARR Start                                                  int64
# BumpOut75K                                               float64
# growth_percent                                           float64
# Product 1                                                  int64
# Product 2                                                  int64
# Product 3                                                  int64
# Product 4                                                  int64
# Product 5                                                  int64
# Product 6                                                  int64
# Product 7                                                  int64
# Product 8                                                  int64
# ...

# %% [markdown]
# MODEL WITH # vs % of revenue growth in one year

# %%
#Linear

X= dummies.drop(["ARR Year Growth", "growth_percent", "Model "], axis = "columns")
y=dummies.loc[:,"ARR Year Growth"]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

from sklearn.linear_model import LinearRegression 

lr= LinearRegression()

lr.fit(X_train, y_train)

print(lr.score(X_test, y_test))
print(lr.score(X_train, y_train))
# Out:
# 0.11272628843572219
# 0.19613879120338973

# %% [markdown]
# Model with % vs #

# %%
X= dummies.drop(["ARR Year Growth", "growth_percent", "Model "], axis = "columns")
y=dummies.loc[:,"growth_percent"]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

from sklearn.linear_model import LinearRegression 

lr2= LinearRegression()

lr2.fit(X_train, y_train)

print(lr2.score(X_test, y_test))
print(lr2.score(X_train, y_train))
# Out:
# 0.0689059379356105
# 0.1755144569890088

# %%
#better numbers when using exact numbers and not percentages

# %%
fig, ax=plt.subplots(figsize=(20,10))
ax=sns.heatmap(dummies.corr(), vmin=-1, vmax=1, cmap=sns.diverging_palette(220,10, n=11), ax=ax)

# %%
dummies.corr()
# Out:
#                                                     DaysSinceLive  \
# DaysSinceLive                                            1.000000
# EE Year Count                                            0.455407
# ARR Year Growth                                          0.032750
# ARR Start                                               -0.235599
# growth_percent                                           0.054554
# Product 1                                                0.080889
# Product 2                                               -0.110084
# Product 3                                               -0.427219
# Product 4                                               -0.593558
# Product 5                                               -0.447997
# Product 6                                               -0.359429
# Product 7                                               -0.319102
# Product 8                                               -0.050202
# ...

# %%
#with actual number as target and no feature engineering

X= dummies.drop(["ARR Year Growth", "growth_percent", "Model "], axis = "columns")
y=dummies.loc[:,"ARR Year Growth"]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

from sklearn.ensemble import RandomForestRegressor

rfr=RandomForestRegressor(n_estimators=100, max_depth=3, oob_score=True)

rfr.fit(X_train, y_train)

print(rfr.score(X_train, y_train))
print(rfr.score(X_test, y_test))
# Out:
# 0.3988551388914578
# 0.2715408420366179

# %%
rfr.feature_importances_
# Out:
# array([5.85664055e-03, 2.80130821e-02, 2.88823112e-01, 3.60151220e-04,
#        1.20308639e-02, 0.00000000e+00, 4.59551077e-03, 0.00000000e+00,
#        1.90715103e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 4.18637832e-03,
#        0.00000000e+00, 2.28628707e-03, 3.15642562e-02, 0.00000000e+00,
#        3.08955955e-04, 1.42592022e-02, 1.70111741e-01, 1.83749883e-01,
#        3.06773009e-02, 1.45132676e-01, 1.66246557e-02, 1.44210204e-02,
#        0.00000000e+00, 3.76916029e-04, 0.00000000e+00, 1.75505609e-02,
#        2.99162852e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.66969760e-03, 0.00000000e+00, 2.17307802e-02, 0.00000000e+00,
#        1.65071146e-03, 2.43350873e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 8.41563233e-04, 0.00000000e+00, 0.00000000e+00,
#        4.60002958e-04, 0.00000000e+00, 2.68385016e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00])

# %%
#feature_col = dummies.columns[dummies.drop("ARR Year Growth", "growth_percent", "Model ")
#feature_col
#sorted(zip(rfr.feature_importances_, feature_cols))[::-1]




feature_imp=list(zip(dummies.select_dtypes(['int64', 'float64'])
         .dropna(axis='columns')
         .drop(["ARR Year Growth", "growth_percent", "Model "], axis='columns'),
    rfr.feature_importances_)
)
feature_imp
# Calculate the total amount that MSE decreases due to splits over a given feature, averaged over all trees. Higher numbers most important
# Out:
# [('DaysSinceLive', 0.0028244468343605524),
#  ('EE Year Count', 0.02654974666211191),
#  ('ARR Start', 0.275754973733443),
#  ('Product 1', 0.0012481871779583737),
#  ('Product 2 ', 0.01287549511886754),
#  ('Product 3', 0.0),
#  ('Product 4', 0.007570878170142585),
#  ('Product 5', 0.0012977806430366121),
#  ('Product 6', 0.0010480400642345208),
#  ('Product 7', 0.006955997505894681),
#  ('Product 8', 0.0),
#  ('Product 9', 0.0),
#  ('Product 10', 0.0),
#  ('Product 11', 0.0),
#  ('Product 12', 0.0),
#  ('Product 13', 0.0038144415113789743),
#  ('Product 14', 0.0),
#  ('Product 15', 0.0011312294921705917),
#  ('Product 16', 0.03494545931285463),
#  ('Product 17', 0.0010753899178451844),
#  ('Product 18', 0.0009324534922090842),
#  ('Total Product Count', 0.019661309704954374),
#  ('Training Hours', 0.1829068899577794),
#  ('Training Students', 0.2024577992603092),
#  ('Percent of Book', 0.024613131205119168),
#  ('ACT Score', 0.12881640056969423),
# ...

# %%
rfr.oob_score_
# Out:
# 0.20542463121275156

# %%
X= dummies.drop(["ARR Year Growth", "growth_percent", "Model "], axis = "columns")
y=dummies.loc[:,"ARR Year Growth"]
max_depth_range = list(range(1, 10))

# %%
from sklearn.model_selection import cross_val_score, KFold
scores = []

kf=KFold(n_splits=10, shuffle=True)

for depth in max_depth_range:
    rfr_reg = RandomForestRegressor(max_depth=depth, random_state=1)
    scores.append(cross_val_score(rfr_reg, X, y, cv=kf).mean())
    
scores
# Out:
# /Users/andreaflores/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/andreaflores/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/andreaflores/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/andreaflores/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
fig, ax = plt.subplots()
ax.plot(max_depth_range, scores);
ax.set_xlabel('max_depth');
ax.set_ylabel('R^2');

# %%
##recommending max depth of 5

# %%
# with % growth as target 
X= dummies.drop(["ARR Year Growth", "growth_percent", "Model "], axis = "columns")
y=dummies.loc[:,"growth_percent"]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

from sklearn.ensemble import RandomForestRegressor

rfr=RandomForestRegressor(n_estimators=100)

rfr.fit(X_train, y_train)

print(rfr.score(X_train, y_train))
print(rfr.score(X_test, y_test))
# Out:
# 0.8829150946297805
# 0.21197627740678537

# %% [markdown]
# More feature engineering:

# %%
dummies.loc[:,"BI Score"]= np.log(dummies.loc[:,"BI Score"])

# %%
dummies.loc[:,"BI Score"].hist();

# %%
dummies.loc[:,"EE Year Count"]= np.log(dummies.loc[:,"EE Year Count"])

# %%
dummies.loc[:,"EE Year Count"].hist();

# %%
dummies.loc[:, "Percent of Book"].hist(bins=150);

# %%
dummies.loc[:, "Percent of Book"].describe()
# Out:
# count    1099.000000
# mean        1.880357
# std         7.296462
# min         0.000000
# 25%         1.153907
# 50%         1.420044
# 75%         1.788770
# max       241.015500
# Name: Percent of Book, dtype: float64

# %%
#dummies.loc[:,"Percent of Book"]= np.log(dummies.loc[:,"Percent of Book"])

# %%
#dummies.loc[:,"Percent of Book"].hist();

# %%
#dummies.loc[:,"Training Hours"]= np.log(dummies.loc[:,"Training Hours"])
#dummies.loc[:,"Training Students"]= np.log(dummies.loc[:,"Training Students"])
#getting errors when trying to take log the two variables above

# %%
dummies.loc[:, "Training Students_sqrd"]= dummies.loc[:, "Training Students"]**2
dummies.loc[:, "Training Hours_sqrd"] = dummies.loc[:,"Training Hours"]**2

# %% [markdown]
# Moving forward with actual # as target not %

# %%
X= dummies.drop(["ARR Year Growth", "growth_percent", "Model "], axis = "columns")
y=dummies.loc[:,"ARR Year Growth"]
from sklearn import metrics

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

from sklearn.linear_model import LinearRegression 

lr_logs= LinearRegression()

lr_logs.fit(X_train, y_train)

print(lr_logs.score(X_test, y_test))
print(lr_logs.score(X_train, y_train))
# Out:
# 0.13394248217506677
# 0.21253927449159524

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

from sklearn.tree import DecisionTreeRegressor

dtr=DecisionTreeRegressor(max_depth=3)

dtr.fit(X_train, y_train)

print(dtr.score(X_train, y_train))
print(dtr.score(X_test, y_test))
# Out:
# 0.324990496903957
# 0.24728354791930238

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10)

from sklearn.ensemble import RandomForestRegressor

rfr=RandomForestRegressor(n_estimators=100, max_depth=3)

rfr.fit(X_train, y_train)

print(rfr.score(X_train, y_train))
print(rfr.score(X_test, y_test))
# Out:
# 0.38997500040840216
# 0.2310142720749182

# %%
target_col="ARR Year Growth"
X_train = dummies.drop([target_col, "growth_percent", "Model "], axis='columns')
y_train = dummies.loc[:, target_col]
X_test = dummies.drop([target_col, "growth_percent", "Model "], axis='columns')
y_test = dummies.loc[:, target_col]


from sklearn.ensemble import BaggingRegressor

bagreg = BaggingRegressor(DecisionTreeRegressor(), n_estimators=500, bootstrap=True, oob_score=True, random_state=1)

bagreg.fit(X_train, y_train)

print(bagreg.score(X_train, y_train))
#print(bagreg.score(X_test, y_test))
print(bagreg.oob_score_)
# Out:
# 0.8966969748130079
# 0.25343678273442105

# %%
X_train.columns
# Out:
# Index(['DaysSinceLive', 'EE Year Count', 'ARR Start', 'Product 1',
#        'Product 2 ', 'Product 3', 'Product 4', 'Product 5', 'Product 6',
#        'Product 7', 'Product 8', 'Product 9', 'Product 10', 'Product 11',
#        'Product 12', 'Product 13', 'Product 14', 'Product 15', 'Product 16',
#        'Product 17', 'Product 18', 'Total Product Count', 'Training Hours',
#        'Training Students', 'Percent of Book', 'ACT Score', 'Ave P_Score',
#        'Industry _Agriculture and Natural Resources', 'Industry _Construction',
#        'Industry _Education', 'Industry _Finance and Insurance',
#        'Industry _Healthcare', 'Industry _Manufacturing',
#        'Industry _Non-Profits, Membership, and Human Services',
#        'Industry _Public Sector', 'Industry _Real Estate',
#        'Industry _Restaurants and Hospitality', 'Industry _Retail',
#        'Industry _Sports and Entertainment',
#        'Industry _Transportation and Warehousing',
# ...

# %%
X_train.columns
# Out:
# Index(['DaysSinceLive', 'EE Year Count', 'ARR Start', 'Product 1',
#        'Product 2 ', 'Product 3', 'Product 4', 'Product 5', 'Product 6',
#        'Product 7', 'Product 8', 'Product 9', 'Product 10', 'Product 11',
#        'Product 12', 'Product 13', 'Product 14', 'Product 15', 'Product 16',
#        'Product 17', 'Product 18', 'Total Product Count', 'Training Hours',
#        'Training Students', 'Percent of Book', 'ACT Score', 'BI Score',
#        'Ave P_Score', 'Industry _Agriculture and Natural Resources',
#        'Industry _Construction', 'Industry _Education',
#        'Industry _Finance and Insurance', 'Industry _Healthcare',
#        'Industry _Manufacturing',
#        'Industry _Non-Profits, Membership, and Human Services',
#        'Industry _Public Sector', 'Industry _Real Estate',
#        'Industry _Restaurants and Hospitality', 'Industry _Retail',
#        'Industry _Sports and Entertainment',
#        'Industry _Transportation and Warehousing',
# ...

# %%
#Tuning the Decision Tree: 


from sklearn.model_selection import cross_val_score, KFold

target_col= "ARR Year Growth"

X= dummies.drop([target_col, "growth_percent", "Model "], axis = "columns")
y=dummies.loc[:,target_col]

kf=KFold(n_splits=len(X), shuffle=True)

dtr=DecisionTreeRegressor(max_depth=2, random_state=1)

scores =cross_val_score(dtr, X, y, cv=kf)
r2=np.array(scores).mean()
r2
# Out:
# 0.0

# %%
#Tuning the Decision Tree: 

from sklearn.model_selection import cross_val_score, KFold

target_col= "ARR Year Growth"

X= dummies.drop([target_col, "growth_percent", "Model "], axis = "columns")
y=dummies.loc[:,target_col]

kf = KFold(n_splits=len(X), shuffle=True)

dtr = DecisionTreeRegressor(max_depth=3, random_state=1)
scores = cross_val_score(dtr, X, y, cv=kf)
r2 = np.array(scores).mean()
r2
# Out:
# 0.0

# %% [markdown]
# Tried to use R2 as metric for loop above but was not working not sure why

# %%
#Tuning the Decision Tree: 
import numpy as np
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import cross_val_score, KFold

target_col= "ARR Year Growth"

X= dummies.drop([target_col, "growth_percent", "Model "], axis = "columns")
y=dummies.loc[:,target_col]

kf = KFold(n_splits=len(X), shuffle=True)

dtr = DecisionTreeRegressor(max_depth=1, random_state=1)
scores = cross_val_score(dtr, X, y, cv=kf, scoring='neg_mean_squared_error')
mse = -np.array(scores).mean()
rmse = np.sqrt(mse)
rmse
# Out:
# 10439.276663274228

# %%
max_depth_range = range(1, 8)

rmse_scores = []

for depth in max_depth_range:
    dtr = DecisionTreeRegressor(max_depth=depth, random_state=1)
    neg_mse_scores = cross_val_score(dtr, X, y, cv=kf, scoring='neg_mean_squared_error')
    mse_scores = -np.array(neg_mse_scores)
    mse_ave_score = mse_scores.mean()
    rmse_ave_score = np.sqrt(mse_ave_score)
    rmse_scores.append(rmse_ave_score)
rmse_scores
# Out:
# [10439.276663274228,
#  10507.304172763797,
#  10705.887119262494,
#  11077.280221030604,
#  11911.3245022561,
#  12021.291115521943,
#  12308.375465494006]

# %%
# Plot max_depth (x-axis) versus RMSE (y-axis).
fig, ax = plt.subplots()
ax.plot(max_depth_range, rmse_scores)
ax.set_xlabel('max_depth')
ax.set_ylabel('RMSE (lower is better)');

# %%
#loop above indicating that the best max depth for decision tree is 1 
#but its actually 3 on the model I did above (by just plugging in all options manually
