# %% [markdown]
# The target variable you want to predict:
# 1-year account revenue growth ( in $)
#
# How predicting that target variable could help with some kind of decision:
# Resource and staffing
#
# The features you want to use to predict that target variable:
# account descriptive data and product usage data
#
# Goals and success metrics:
# Linear regression: R squared/ MSE
#
# Risks or limitations:
# Only using a subset of customer - smallest accounts
# Pulled two years worth of data, in an effort to have more data
# if an account was active both years I split up the data into two rows( may only use the most recent year- if there appears to be isssue with having 2 rows per account)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

project = pd.read_csv('../part1/Project_data.csv')
project.head()
# Out:
#    Obs_No     AR #  Obs Year Year Live  DaysSinceLive  EE Year Count  \
# 0       1  ABE1000      2017      2011           1823            217
# 1       2  ABE1000      2018      2011           2188            218
# 2       3  ABI1002      2018      2016            240            381
# 3       4  ACC1004      2017      2010           2261            220
# 4       5  ACC1004      2018      2010           2626            220
#
#    ARR Year Growth  ARR Start  ARR_EndOfYear  BOut75K   ...    \
# 0           4753.0      66054        70807.0      0.0   ...
# 1           5866.0      70807        76673.0      1.0   ...
# 2          39173.0      73369       112542.0      1.0   ...
# 3           3192.0      31944        35136.0      0.0   ...
# 4           3504.0      35136        38640.0      0.0   ...
#
#    Category_Account Health  RefNo_Cumulative  Conference Attendance  \
# 0                        1                 0                      0
# ...
